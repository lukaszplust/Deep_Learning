# %% [markdown]
# <a href="https://colab.research.google.com/github/lukaszplust/Deep_Learning/blob/main/Activation_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ReLU
#
# ### $f(x) = max(x,0)$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()#ustawia tło domyslnie z biblioteki seaborn

# %%
def relu(x):
  return max(x,0)

# %%
for i in [-10, -5, 0, 5, 10]:
  print(relu(i))
# Out:
# 0
# 0
# 0
# 5
# 10

# %% [markdown]
# Relu plot

# %%
data_relu = np.arange(-10, 20, 0.1) # wartosci od -10 do 20 z krokiem 0.1

# %%
plotting_data_relu = [relu(x) for x in data_relu]

# %%
plt.plot(data_relu, plotting_data_relu)
plt.title("Function ReLU")
plt.xlabel("Input data")
plt.ylabel("Calculated values")
# Out:
# Text(0, 0.5, 'Calculated values')

# %% [markdown]
# ### SIGMOID
#
# ### $ f(x) = \frac{1}{1+e^{-x}}$

# %%
def sigmoid(x):
  return 1 / (1.0 + np.exp(-x))

# %%
for i in [-10, -7, -3, -1, 0 ,1, 3, 7, 10]:
  print(sigmoid(i))
# Out:
# 4.5397868702434395e-05
# 0.0009110511944006454
# 0.04742587317756678
# 0.2689414213699951
# 0.5
# 0.7310585786300049
# 0.9525741268224334
# 0.9990889488055994
# 0.9999546021312976

# %%
data_sigmoid = np.arange(-10, 10, 0.1) # wartosci od -10 do 20 z krokiem 0.1

# %%
plotting_data_sigmoid = [sigmoid(x) for x in data_sigmoid]

# %%
plt.plot(data_sigmoid, plotting_data_sigmoid)
plt.title("Function Sigmoid")
plt.xlabel("Input data")
plt.ylabel("Calculated values")
# Out:
# Text(0, 0.5, 'Calculated values')

# %% [markdown]
# ### SOFTMAX

# %%
data_soft_max = np.random.rand(3, 5)

# %%
data_soft_max = pd.DataFrame(data_soft_max)
data_soft_max
# Out:
#           0         1         2         3         4
# 0  0.237534  0.816250  0.960190  0.751158  0.485376
# 1  0.100873  0.936636  0.686319  0.500718  0.914572
# 2  0.117641  0.429185  0.774249  0.033404  0.259053

# %%
calculated_softmax = np.exp(data_soft_max) / np.exp(data_soft_max).sum()

# %%
calculated_softmax.sum()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# dtype: float64

# %% [markdown]
# TAN H

# %%
def tanh(x):
  return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

# %%
for i in [-10, -7, -3, -1, 0 ,1, 3, 7, 10]:
  print(tanh(i))
# Out:
# -0.9999999958776926
# -0.9999983369439447
# -0.9950547536867306
# -0.7615941559557649
# 0.0
# 0.7615941559557649
# 0.9950547536867306
# 0.9999983369439447
# 0.9999999958776926

# %%
data_tanh = np.arange(-10, 10, 0.1) # wartosci od -10 do 20 z krokiem 0.1

# %%
plotting_data_tanh = [tanh(x) for x in data_tanh]

# %%
plt.plot(data_tanh, plotting_data_tanh)
plt.title("Function Tanh")
plt.xlabel("Input data")
plt.ylabel("Calculated values")
# Out:
# Text(0, 0.5, 'Calculated values')
